# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv("fer2013.csv")

# %%
#print(ds.head)
#type(ds)
pix=[]
for i in ds["pixels"]:
    pix.append(list(map(int, i.split())))

# %%
npx=np.array(pix)

# %%
npx.shape
# Out:
# (35887, 2304)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
plt.imshow(255 - npx[6].reshape(48,48),cmap=plt.cm.binary )

# %%
X=[i.reshape(48,48) for i in npx]

# %%
X=np.array(X)

# %%
X.shape
# Out:
# (35887, 48, 48)

# %%
plt.imshow(255 - X[10], cmap=plt.cm.binary)

# %%
for i in range(len(X)):
    X[i]=255-X[i]

# %%
plt.imshow(X[105], cmap=plt.cm.binary)

# %%
np.save("X",X)

# %%
aX=np.load("X.npy")

# %%
plt.imshow(aX[9], cmap=plt.cm.binary)

# %%
ds["emotion"][9]
# Out:
# 2

# %%
set(ds["emotion"])
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
for i in range(0,27):
    if ds["emotion"][i]==4:
        plt.imshow(aX[i], cmap=plt.cm.binary)
        plt.show()

# %%
emotion=["angry","disgust","fear","happy","sad","surprised","neutral"]

# %%
y = np.array(ds["emotion"])

# %%
np.save("y",y)

# %%
import cv2
